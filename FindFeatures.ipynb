# %%
import argparse as ap
import cv2
import numpy as np
import os

from sklearn.externals import joblib
from scipy.cluster.vq import *

from sklearn import preprocessing
from rootsift import RootSIFT
import math

# %%
train_path = "Dataset"

training_names = os.listdir(train_path)

# %%
numWords = 1000
image_paths = []

# %%
for training_name in training_names:
    image_path = os.path.join(train_path, training_name)
    image_paths += [image_path]

# Create feature extraction and keypoint detector objects
#fea_det = cv2.xfeatures2d.SIFT_create()
#des_ext = cv2.xfeatures2d.SIFT_create()

# List where all the descriptors are stored
des_list = []

# %%
print(len(image_paths))
# Out:
# 4000

# %%
for i, image_path in enumerate(image_paths):
    im = cv2.imread(image_path)
    print("Extract SIFT of %s image, %d of %d images" %(training_names[i], i, len(image_paths)))
    #kpts = fea_det.detect(im)
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sift = cv2.xfeatures2d.SIFT_create()
    (kps, descs) = sift.detectAndCompute(gray, None)
    #kpts, des = des_ext.compute(im, kpts)
    # rootsift
    #rs = RootSIFT()
    #des = rs.compute(kpts, des)
    des_list.append((image_path, descs))
# Out:
# Extract SIFT of 1.jpg image, 0 of 4000 images
# Extract SIFT of 10.jpg image, 1 of 4000 images
# Extract SIFT of 100.jpg image, 2 of 4000 images
# Extract SIFT of 1000.jpg image, 3 of 4000 images
# Extract SIFT of 1001.jpg image, 4 of 4000 images
# Extract SIFT of 1002.jpg image, 5 of 4000 images
# Extract SIFT of 1003.jpg image, 6 of 4000 images
# Extract SIFT of 1004.jpg image, 7 of 4000 images
# Extract SIFT of 1005.jpg image, 8 of 4000 images
# Extract SIFT of 1006.jpg image, 9 of 4000 images
# Extract SIFT of 1007.jpg image, 10 of 4000 images
# Extract SIFT of 1008.jpg image, 11 of 4000 images
# Extract SIFT of 1009.jpg image, 12 of 4000 images
# Extract SIFT of 101.jpg image, 13 of 4000 images
# Extract SIFT of 1010.jpg image, 14 of 4000 images
# Extract SIFT of 1011.jpg image, 15 of 4000 images
# Extract SIFT of 1012.jpg image, 16 of 4000 images
# Extract SIFT of 1013.jpg image, 17 of 4000 images
# Extract SIFT of 1014.jpg image, 18 of 4000 images
# Extract SIFT of 1015.jpg image, 19 of 4000 images
# Extract SIFT of 1016.jpg image, 20 of 4000 images
# Extract SIFT of 1017.jpg image, 21 of 4000 images
# Extract SIFT of 1018.jpg image, 22 of 4000 images
# Extract SIFT of 1019.jpg image, 23 of 4000 images
# Extract SIFT of 102.jpg image, 24 of 4000 images
# Extract SIFT of 1020.jpg image, 25 of 4000 images
# Extract SIFT of 1021.jpg image, 26 of 4000 images
# Extract SIFT of 1022.jpg image, 27 of 4000 images
# Extract SIFT of 1023.jpg image, 28 of 4000 images
# Extract SIFT of 1024.jpg image, 29 of 4000 images
# Extract SIFT of 1025.jpg image, 30 of 4000 images
# Extract SIFT of 1026.jpg image, 31 of 4000 images
# Extract SIFT of 1027.jpg image, 32 of 4000 images
# Extract SIFT of 1028.jpg image, 33 of 4000 images
# Extract SIFT of 1029.jpg image, 34 of 4000 images
# Extract SIFT of 103.jpg image, 35 of 4000 images
# Extract SIFT of 1030.jpg image, 36 of 4000 images
# Extract SIFT of 1031.jpg image, 37 of 4000 images
# Extract SIFT of 1032.jpg image, 38 of 4000 images
# Extract SIFT of 1033.jpg image, 39 of 4000 images
# Extract SIFT of 1034.jpg image, 40 of 4000 images
# Extract SIFT of 1035.jpg image, 41 of 4000 images
# Extract SIFT of 1036.jpg image, 42 of 4000 images
# Extract SIFT of 1037.jpg image, 43 of 4000 images
# Extract SIFT of 1038.jpg image, 44 of 4000 images
# Extract SIFT of 1039.jpg image, 45 of 4000 images
# Extract SIFT of 104.jpg image, 46 of 4000 images
# Extract SIFT of 1040.jpg image, 47 of 4000 images
# Extract SIFT of 1041.jpg image, 48 of 4000 images
# Extract SIFT of 1042.jpg image, 49 of 4000 images
# Extract SIFT of 1043.jpg image, 50 of 4000 images
# Extract SIFT of 1044.jpg image, 51 of 4000 images
# Extract SIFT of 1045.jpg image, 52 of 4000 images
# Extract SIFT of 1046.jpg image, 53 of 4000 images
# Extract SIFT of 1047.jpg image, 54 of 4000 images
# Extract SIFT of 1048.jpg image, 55 of 4000 images
# Extract SIFT of 1049.jpg image, 56 of 4000 images
# Extract SIFT of 105.jpg image, 57 of 4000 images
# Extract SIFT of 1050.jpg image, 58 of 4000 images
# Extract SIFT of 1051.jpg image, 59 of 4000 images
# Extract SIFT of 1052.jpg image, 60 of 4000 images
# Extract SIFT of 1053.jpg image, 61 of 4000 images
# Extract SIFT of 1054.jpg image, 62 of 4000 images
# Extract SIFT of 1055.jpg image, 63 of 4000 images
# Extract SIFT of 1056.jpg image, 64 of 4000 images
# Extract SIFT of 1057.jpg image, 65 of 4000 images
# Extract SIFT of 1058.jpg image, 66 of 4000 images
# Extract SIFT of 1059.jpg image, 67 of 4000 images
# Extract SIFT of 106.jpg image, 68 of 4000 images
# Extract SIFT of 1060.jpg image, 69 of 4000 images
# Extract SIFT of 1061.jpg image, 70 of 4000 images
# Extract SIFT of 1062.jpg image, 71 of 4000 images
# Extract SIFT of 1063.jpg image, 72 of 4000 images
# Extract SIFT of 1064.jpg image, 73 of 4000 images
# Extract SIFT of 1065.jpg image, 74 of 4000 images
# Extract SIFT of 1066.jpg image, 75 of 4000 images
# Extract SIFT of 1067.jpg image, 76 of 4000 images
# Extract SIFT of 1068.jpg image, 77 of 4000 images
# Extract SIFT of 1069.jpg image, 78 of 4000 images
# Extract SIFT of 107.jpg image, 79 of 4000 images
# Extract SIFT of 1070.jpg image, 80 of 4000 images
# Extract SIFT of 1071.jpg image, 81 of 4000 images
# Extract SIFT of 1072.jpg image, 82 of 4000 images
# Extract SIFT of 1073.jpg image, 83 of 4000 images
# Extract SIFT of 1074.jpg image, 84 of 4000 images
# Extract SIFT of 1075.jpg image, 85 of 4000 images
# Extract SIFT of 1076.jpg image, 86 of 4000 images
# Extract SIFT of 1077.jpg image, 87 of 4000 images
# Extract SIFT of 1078.jpg image, 88 of 4000 images
# Extract SIFT of 1079.jpg image, 89 of 4000 images
# Extract SIFT of 108.jpg image, 90 of 4000 images
# Extract SIFT of 1080.jpg image, 91 of 4000 images
# Extract SIFT of 1081.jpg image, 92 of 4000 images
# Extract SIFT of 1082.jpg image, 93 of 4000 images
# Extract SIFT of 1083.jpg image, 94 of 4000 images
# Extract SIFT of 1084.jpg image, 95 of 4000 images
# Extract SIFT of 1085.jpg image, 96 of 4000 images
# Extract SIFT of 1086.jpg image, 97 of 4000 images
# Extract SIFT of 1087.jpg image, 98 of 4000 images
# Extract SIFT of 1088.jpg image, 99 of 4000 images
# Extract SIFT of 1089.jpg image, 100 of 4000 images
# Extract SIFT of 109.jpg image, 101 of 4000 images
# Extract SIFT of 1090.jpg image, 102 of 4000 images
# Extract SIFT of 1091.jpg image, 103 of 4000 images
# Extract SIFT of 1092.jpg image, 104 of 4000 images
# Extract SIFT of 1093.jpg image, 105 of 4000 images
# Extract SIFT of 1094.jpg image, 106 of 4000 images
# Extract SIFT of 1095.jpg image, 107 of 4000 images
# Extract SIFT of 1096.jpg image, 108 of 4000 images
# Extract SIFT of 1097.jpg image, 109 of 4000 images
# Extract SIFT of 1098.jpg image, 110 of 4000 images
# Extract SIFT of 1099.jpg image, 111 of 4000 images
# Extract SIFT of 11.jpg image, 112 of 4000 images
# Extract SIFT of 110.jpg image, 113 of 4000 images
# Extract SIFT of 1100.jpg image, 114 of 4000 images
# Extract SIFT of 1101.jpg image, 115 of 4000 images
# Extract SIFT of 1102.jpg image, 116 of 4000 images
# Extract SIFT of 1103.jpg image, 117 of 4000 images
# Extract SIFT of 1104.jpg image, 118 of 4000 images
# Extract SIFT of 1105.jpg image, 119 of 4000 images
# Extract SIFT of 1106.jpg image, 120 of 4000 images
# Extract SIFT of 1107.jpg image, 121 of 4000 images
# Extract SIFT of 1108.jpg image, 122 of 4000 images
# Extract SIFT of 1109.jpg image, 123 of 4000 images
# Extract SIFT of 111.jpg image, 124 of 4000 images
# Extract SIFT of 1110.jpg image, 125 of 4000 images
# Extract SIFT of 1111.jpg image, 126 of 4000 images
# Extract SIFT of 1112.jpg image, 127 of 4000 images
# Extract SIFT of 1113.jpg image, 128 of 4000 images
# Extract SIFT of 1114.jpg image, 129 of 4000 images
# Extract SIFT of 1115.jpg image, 130 of 4000 images
# Extract SIFT of 1116.jpg image, 131 of 4000 images
# Extract SIFT of 1117.jpg image, 132 of 4000 images
# Extract SIFT of 1118.jpg image, 133 of 4000 images
# Extract SIFT of 1119.jpg image, 134 of 4000 images
# Extract SIFT of 112.jpg image, 135 of 4000 images
# Extract SIFT of 1120.jpg image, 136 of 4000 images
# Extract SIFT of 1121.jpg image, 137 of 4000 images
# Extract SIFT of 1122.jpg image, 138 of 4000 images
# Extract SIFT of 1123.jpg image, 139 of 4000 images
# Extract SIFT of 1124.jpg image, 140 of 4000 images
# Extract SIFT of 1125.jpg image, 141 of 4000 images
# Extract SIFT of 1126.jpg image, 142 of 4000 images
# Extract SIFT of 1127.jpg image, 143 of 4000 images
# Extract SIFT of 1128.jpg image, 144 of 4000 images
# Extract SIFT of 1129.jpg image, 145 of 4000 images
# Extract SIFT of 113.jpg image, 146 of 4000 images
# Extract SIFT of 1130.jpg image, 147 of 4000 images
# Extract SIFT of 1131.jpg image, 148 of 4000 images
# Extract SIFT of 1132.jpg image, 149 of 4000 images
# Extract SIFT of 1133.jpg image, 150 of 4000 images
# Extract SIFT of 1134.jpg image, 151 of 4000 images
# Extract SIFT of 1135.jpg image, 152 of 4000 images
# Extract SIFT of 1136.jpg image, 153 of 4000 images
# Extract SIFT of 1137.jpg image, 154 of 4000 images
# Extract SIFT of 1138.jpg image, 155 of 4000 images
# Extract SIFT of 1139.jpg image, 156 of 4000 images
# Extract SIFT of 114.jpg image, 157 of 4000 images
# Extract SIFT of 1140.jpg image, 158 of 4000 images
# Extract SIFT of 1141.jpg image, 159 of 4000 images
# Extract SIFT of 1142.jpg image, 160 of 4000 images
# Extract SIFT of 1143.jpg image, 161 of 4000 images
# Extract SIFT of 1144.jpg image, 162 of 4000 images
# Extract SIFT of 1145.jpg image, 163 of 4000 images
# Extract SIFT of 1146.jpg image, 164 of 4000 images
# Extract SIFT of 1147.jpg image, 165 of 4000 images
# Extract SIFT of 1148.jpg image, 166 of 4000 images
# Extract SIFT of 1149.jpg image, 167 of 4000 images
# Extract SIFT of 115.jpg image, 168 of 4000 images
# Extract SIFT of 1150.jpg image, 169 of 4000 images
# Extract SIFT of 1151.jpg image, 170 of 4000 images
# Extract SIFT of 1152.jpg image, 171 of 4000 images
# Extract SIFT of 1153.jpg image, 172 of 4000 images
# Extract SIFT of 1154.jpg image, 173 of 4000 images
# Extract SIFT of 1155.jpg image, 174 of 4000 images
# Extract SIFT of 1156.jpg image, 175 of 4000 images
# Extract SIFT of 1157.jpg image, 176 of 4000 images
# Extract SIFT of 1158.jpg image, 177 of 4000 images
# Extract SIFT of 1159.jpg image, 178 of 4000 images
# Extract SIFT of 116.jpg image, 179 of 4000 images
# Extract SIFT of 1160.jpg image, 180 of 4000 images
# Extract SIFT of 1161.jpg image, 181 of 4000 images
# Extract SIFT of 1162.jpg image, 182 of 4000 images
# Extract SIFT of 1163.jpg image, 183 of 4000 images
# Extract SIFT of 1164.jpg image, 184 of 4000 images
# Extract SIFT of 1165.jpg image, 185 of 4000 images
# Extract SIFT of 1166.jpg image, 186 of 4000 images
# Extract SIFT of 1167.jpg image, 187 of 4000 images
# Extract SIFT of 1168.jpg image, 188 of 4000 images
# Extract SIFT of 1169.jpg image, 189 of 4000 images
# Extract SIFT of 117.jpg image, 190 of 4000 images
# Extract SIFT of 1170.jpg image, 191 of 4000 images
# Extract SIFT of 1171.jpg image, 192 of 4000 images
# Extract SIFT of 1172.jpg image, 193 of 4000 images
# Extract SIFT of 1173.jpg image, 194 of 4000 images
# Extract SIFT of 1174.jpg image, 195 of 4000 images
# Extract SIFT of 1175.jpg image, 196 of 4000 images
# Extract SIFT of 1176.jpg image, 197 of 4000 images
# Extract SIFT of 1177.jpg image, 198 of 4000 images
# Extract SIFT of 1178.jpg image, 199 of 4000 images
# Extract SIFT of 1179.jpg image, 200 of 4000 images
# Extract SIFT of 118.jpg image, 201 of 4000 images
# Extract SIFT of 1180.jpg image, 202 of 4000 images
# Extract SIFT of 1181.jpg image, 203 of 4000 images
# Extract SIFT of 1182.jpg image, 204 of 4000 images
# Extract SIFT of 1183.jpg image, 205 of 4000 images
# Extract SIFT of 1184.jpg image, 206 of 4000 images
# Extract SIFT of 1185.jpg image, 207 of 4000 images
# Extract SIFT of 1186.jpg image, 208 of 4000 images
# Extract SIFT of 1187.jpg image, 209 of 4000 images
# Extract SIFT of 1188.jpg image, 210 of 4000 images
# Extract SIFT of 1189.jpg image, 211 of 4000 images
# Extract SIFT of 119.jpg image, 212 of 4000 images
# Extract SIFT of 1190.jpg image, 213 of 4000 images
# Extract SIFT of 1191.jpg image, 214 of 4000 images
# Extract SIFT of 1192.jpg image, 215 of 4000 images
# Extract SIFT of 1193.jpg image, 216 of 4000 images
# Extract SIFT of 1194.jpg image, 217 of 4000 images
# Extract SIFT of 1195.jpg image, 218 of 4000 images
# Extract SIFT of 1196.jpg image, 219 of 4000 images
# Extract SIFT of 1197.jpg image, 220 of 4000 images
# Extract SIFT of 1198.jpg image, 221 of 4000 images
# Extract SIFT of 1199.jpg image, 222 of 4000 images
# Extract SIFT of 12.jpg image, 223 of 4000 images
# Extract SIFT of 120.jpg image, 224 of 4000 images
# Extract SIFT of 1200.jpg image, 225 of 4000 images
# Extract SIFT of 1201.jpg image, 226 of 4000 images
# Extract SIFT of 1202.jpg image, 227 of 4000 images
# Extract SIFT of 1203.jpg image, 228 of 4000 images
# Extract SIFT of 1204.jpg image, 229 of 4000 images
# Extract SIFT of 1205.jpg image, 230 of 4000 images
# Extract SIFT of 1206.jpg image, 231 of 4000 images
# Extract SIFT of 1207.jpg image, 232 of 4000 images
# Extract SIFT of 1208.jpg image, 233 of 4000 images
# Extract SIFT of 1209.jpg image, 234 of 4000 images
# Extract SIFT of 121.jpg image, 235 of 4000 images
# Extract SIFT of 1210.jpg image, 236 of 4000 images
# Extract SIFT of 1211.jpg image, 237 of 4000 images
# Extract SIFT of 1212.jpg image, 238 of 4000 images
# Extract SIFT of 1213.jpg image, 239 of 4000 images
# Extract SIFT of 1214.jpg image, 240 of 4000 images
# Extract SIFT of 1215.jpg image, 241 of 4000 images
# Extract SIFT of 1216.jpg image, 242 of 4000 images
# Extract SIFT of 1217.jpg image, 243 of 4000 images
# Extract SIFT of 1218.jpg image, 244 of 4000 images
# Extract SIFT of 1219.jpg image, 245 of 4000 images
# Extract SIFT of 122.jpg image, 246 of 4000 images
# Extract SIFT of 1220.jpg image, 247 of 4000 images
# Extract SIFT of 1221.jpg image, 248 of 4000 images
# Extract SIFT of 1222.jpg image, 249 of 4000 images
# Extract SIFT of 1223.jpg image, 250 of 4000 images
# Extract SIFT of 1224.jpg image, 251 of 4000 images
# Extract SIFT of 1225.jpg image, 252 of 4000 images
# Extract SIFT of 1226.jpg image, 253 of 4000 images
# Extract SIFT of 1227.jpg image, 254 of 4000 images
# Extract SIFT of 1228.jpg image, 255 of 4000 images
# Extract SIFT of 1229.jpg image, 256 of 4000 images
# Extract SIFT of 123.jpg image, 257 of 4000 images
# Extract SIFT of 1230.jpg image, 258 of 4000 images
# Extract SIFT of 1231.jpg image, 259 of 4000 images
# Extract SIFT of 1232.jpg image, 260 of 4000 images
# Extract SIFT of 1233.jpg image, 261 of 4000 images
# Extract SIFT of 1234.jpg image, 262 of 4000 images
# Extract SIFT of 1235.jpg image, 263 of 4000 images
# Extract SIFT of 1236.jpg image, 264 of 4000 images
# Extract SIFT of 1237.jpg image, 265 of 4000 images
# Extract SIFT of 1238.jpg image, 266 of 4000 images
# Extract SIFT of 1239.jpg image, 267 of 4000 images
# Extract SIFT of 124.jpg image, 268 of 4000 images
# Extract SIFT of 1240.jpg image, 269 of 4000 images
# Extract SIFT of 1241.jpg image, 270 of 4000 images
# Extract SIFT of 1242.jpg image, 271 of 4000 images
# Extract SIFT of 1243.jpg image, 272 of 4000 images
# Extract SIFT of 1244.jpg image, 273 of 4000 images
# Extract SIFT of 1245.jpg image, 274 of 4000 images
# Extract SIFT of 1246.jpg image, 275 of 4000 images
# Extract SIFT of 1247.jpg image, 276 of 4000 images
# Extract SIFT of 1248.jpg image, 277 of 4000 images
# Extract SIFT of 1249.jpg image, 278 of 4000 images
# Extract SIFT of 125.jpg image, 279 of 4000 images
# Extract SIFT of 1250.jpg image, 280 of 4000 images
# Extract SIFT of 1251.jpg image, 281 of 4000 images
# Extract SIFT of 1252.jpg image, 282 of 4000 images
# Extract SIFT of 1253.jpg image, 283 of 4000 images
# Extract SIFT of 1254.jpg image, 284 of 4000 images
# Extract SIFT of 1255.jpg image, 285 of 4000 images
# Extract SIFT of 1256.jpg image, 286 of 4000 images
# Extract SIFT of 1257.jpg image, 287 of 4000 images
# Extract SIFT of 1258.jpg image, 288 of 4000 images
# Extract SIFT of 1259.jpg image, 289 of 4000 images
# Extract SIFT of 126.jpg image, 290 of 4000 images
# Extract SIFT of 1260.jpg image, 291 of 4000 images
# Extract SIFT of 1261.jpg image, 292 of 4000 images
# Extract SIFT of 1262.jpg image, 293 of 4000 images
# Extract SIFT of 1263.jpg image, 294 of 4000 images
# Extract SIFT of 1264.jpg image, 295 of 4000 images
# Extract SIFT of 1265.jpg image, 296 of 4000 images
# Extract SIFT of 1266.jpg image, 297 of 4000 images
# Extract SIFT of 1267.jpg image, 298 of 4000 images
# Extract SIFT of 1268.jpg image, 299 of 4000 images
# Extract SIFT of 1269.jpg image, 300 of 4000 images
# Extract SIFT of 127.jpg image, 301 of 4000 images
# Extract SIFT of 1270.jpg image, 302 of 4000 images
# Extract SIFT of 1271.jpg image, 303 of 4000 images
# Extract SIFT of 1272.jpg image, 304 of 4000 images
# Extract SIFT of 1273.jpg image, 305 of 4000 images
# Extract SIFT of 1274.jpg image, 306 of 4000 images
# Extract SIFT of 1275.jpg image, 307 of 4000 images
# Extract SIFT of 1276.jpg image, 308 of 4000 images
# Extract SIFT of 1277.jpg image, 309 of 4000 images
# Extract SIFT of 1278.jpg image, 310 of 4000 images
# Extract SIFT of 1279.jpg image, 311 of 4000 images
# Extract SIFT of 128.jpg image, 312 of 4000 images
# Extract SIFT of 1280.jpg image, 313 of 4000 images
# Extract SIFT of 1281.jpg image, 314 of 4000 images
# Extract SIFT of 1282.jpg image, 315 of 4000 images
# Extract SIFT of 1283.jpg image, 316 of 4000 images
# Extract SIFT of 1284.jpg image, 317 of 4000 images
# Extract SIFT of 1285.jpg image, 318 of 4000 images
# Extract SIFT of 1286.jpg image, 319 of 4000 images
# Extract SIFT of 1287.jpg image, 320 of 4000 images
# Extract SIFT of 1288.jpg image, 321 of 4000 images
# Extract SIFT of 1289.jpg image, 322 of 4000 images
# Extract SIFT of 129.jpg image, 323 of 4000 images
# Extract SIFT of 1290.jpg image, 324 of 4000 images
# Extract SIFT of 1291.jpg image, 325 of 4000 images
# Extract SIFT of 1292.jpg image, 326 of 4000 images
# Extract SIFT of 1293.jpg image, 327 of 4000 images
# Extract SIFT of 1294.jpg image, 328 of 4000 images
# Extract SIFT of 1295.jpg image, 329 of 4000 images
# Extract SIFT of 1296.jpg image, 330 of 4000 images
# Extract SIFT of 1297.jpg image, 331 of 4000 images
# Extract SIFT of 1298.jpg image, 332 of 4000 images
# Extract SIFT of 1299.jpg image, 333 of 4000 images
# Extract SIFT of 13.jpg image, 334 of 4000 images
# Extract SIFT of 130.jpg image, 335 of 4000 images
# Extract SIFT of 1300.jpg image, 336 of 4000 images
# Extract SIFT of 1301.jpg image, 337 of 4000 images
# Extract SIFT of 1302.jpg image, 338 of 4000 images
# Extract SIFT of 1303.jpg image, 339 of 4000 images
# Extract SIFT of 1304.jpg image, 340 of 4000 images
# Extract SIFT of 1305.jpg image, 341 of 4000 images
# Extract SIFT of 1306.jpg image, 342 of 4000 images
# Extract SIFT of 1307.jpg image, 343 of 4000 images
# Extract SIFT of 1308.jpg image, 344 of 4000 images
# Extract SIFT of 1309.jpg image, 345 of 4000 images
# Extract SIFT of 131.jpg image, 346 of 4000 images
# Extract SIFT of 1310.jpg image, 347 of 4000 images
# Extract SIFT of 1311.jpg image, 348 of 4000 images
# Extract SIFT of 1312.jpg image, 349 of 4000 images
# Extract SIFT of 1313.jpg image, 350 of 4000 images
# Extract SIFT of 1314.jpg image, 351 of 4000 images
# Extract SIFT of 1315.jpg image, 352 of 4000 images
# Extract SIFT of 1316.jpg image, 353 of 4000 images
# Extract SIFT of 1317.jpg image, 354 of 4000 images
# Extract SIFT of 1318.jpg image, 355 of 4000 images
# Extract SIFT of 1319.jpg image, 356 of 4000 images
# Extract SIFT of 132.jpg image, 357 of 4000 images
# Extract SIFT of 1320.jpg image, 358 of 4000 images
# Extract SIFT of 1321.jpg image, 359 of 4000 images
# Extract SIFT of 1322.jpg image, 360 of 4000 images
# Extract SIFT of 1323.jpg image, 361 of 4000 images
# Extract SIFT of 1324.jpg image, 362 of 4000 images
# Extract SIFT of 1325.jpg image, 363 of 4000 images
# Extract SIFT of 1326.jpg image, 364 of 4000 images
# Extract SIFT of 1327.jpg image, 365 of 4000 images
# Extract SIFT of 1328.jpg image, 366 of 4000 images
# Extract SIFT of 1329.jpg image, 367 of 4000 images
# Extract SIFT of 133.jpg image, 368 of 4000 images
# Extract SIFT of 1330.jpg image, 369 of 4000 images
# Extract SIFT of 1331.jpg image, 370 of 4000 images
# Extract SIFT of 1332.jpg image, 371 of 4000 images
# Extract SIFT of 1333.jpg image, 372 of 4000 images
# Extract SIFT of 1334.jpg image, 373 of 4000 images
# Extract SIFT of 1335.jpg image, 374 of 4000 images
# Extract SIFT of 1336.jpg image, 375 of 4000 images
# Extract SIFT of 1337.jpg image, 376 of 4000 images
# Extract SIFT of 1338.jpg image, 377 of 4000 images
# Extract SIFT of 1339.jpg image, 378 of 4000 images
# Extract SIFT of 134.jpg image, 379 of 4000 images
# Extract SIFT of 1340.jpg image, 380 of 4000 images
# Extract SIFT of 1341.jpg image, 381 of 4000 images
# Extract SIFT of 1342.jpg image, 382 of 4000 images
# Extract SIFT of 1343.jpg image, 383 of 4000 images
# Extract SIFT of 1344.jpg image, 384 of 4000 images
# Extract SIFT of 1345.jpg image, 385 of 4000 images
# Extract SIFT of 1346.jpg image, 386 of 4000 images
# Extract SIFT of 1347.jpg image, 387 of 4000 images
# Extract SIFT of 1348.jpg image, 388 of 4000 images
# Extract SIFT of 1349.jpg image, 389 of 4000 images
# Extract SIFT of 135.jpg image, 390 of 4000 images
# Extract SIFT of 1350.jpg image, 391 of 4000 images
# Extract SIFT of 1351.jpg image, 392 of 4000 images
# Extract SIFT of 1352.jpg image, 393 of 4000 images
# Extract SIFT of 1353.jpg image, 394 of 4000 images
# Extract SIFT of 1354.jpg image, 395 of 4000 images
# Extract SIFT of 1355.jpg image, 396 of 4000 images
# Extract SIFT of 1356.jpg image, 397 of 4000 images
# Extract SIFT of 1357.jpg image, 398 of 4000 images
# Extract SIFT of 1358.jpg image, 399 of 4000 images
# Extract SIFT of 1359.jpg image, 400 of 4000 images
# Extract SIFT of 136.jpg image, 401 of 4000 images
# Extract SIFT of 1360.jpg image, 402 of 4000 images
# Extract SIFT of 1361.jpg image, 403 of 4000 images
# Extract SIFT of 1362.jpg image, 404 of 4000 images
# Extract SIFT of 1363.jpg image, 405 of 4000 images
# Extract SIFT of 1364.jpg image, 406 of 4000 images
# Extract SIFT of 1365.jpg image, 407 of 4000 images
# Extract SIFT of 1366.jpg image, 408 of 4000 images
# Extract SIFT of 1367.jpg image, 409 of 4000 images
# Extract SIFT of 1368.jpg image, 410 of 4000 images
# Extract SIFT of 1369.jpg image, 411 of 4000 images
# Extract SIFT of 137.jpg image, 412 of 4000 images
# Extract SIFT of 1370.jpg image, 413 of 4000 images
# Extract SIFT of 1371.jpg image, 414 of 4000 images
# Extract SIFT of 1372.jpg image, 415 of 4000 images
# Extract SIFT of 1373.jpg image, 416 of 4000 images
# Extract SIFT of 1374.jpg image, 417 of 4000 images
# Extract SIFT of 1375.jpg image, 418 of 4000 images
# Extract SIFT of 1376.jpg image, 419 of 4000 images
# Extract SIFT of 1377.jpg image, 420 of 4000 images
# Extract SIFT of 1378.jpg image, 421 of 4000 images
# Extract SIFT of 1379.jpg image, 422 of 4000 images
# Extract SIFT of 138.jpg image, 423 of 4000 images
# Extract SIFT of 1380.jpg image, 424 of 4000 images
# Extract SIFT of 1381.jpg image, 425 of 4000 images
# Extract SIFT of 1382.jpg image, 426 of 4000 images
# Extract SIFT of 1383.jpg image, 427 of 4000 images
# Extract SIFT of 1384.jpg image, 428 of 4000 images
# Extract SIFT of 1385.jpg image, 429 of 4000 images
# Extract SIFT of 1386.jpg image, 430 of 4000 images
# Extract SIFT of 1387.jpg image, 431 of 4000 images
# Extract SIFT of 1388.jpg image, 432 of 4000 images
# Extract SIFT of 1389.jpg image, 433 of 4000 images
# Extract SIFT of 139.jpg image, 434 of 4000 images
# Extract SIFT of 1390.jpg image, 435 of 4000 images
# Extract SIFT of 1391.jpg image, 436 of 4000 images
# Extract SIFT of 1392.jpg image, 437 of 4000 images
# Extract SIFT of 1393.jpg image, 438 of 4000 images
# Extract SIFT of 1394.jpg image, 439 of 4000 images
# Extract SIFT of 1395.jpg image, 440 of 4000 images
# Extract SIFT of 1396.jpg image, 441 of 4000 images
# Extract SIFT of 1397.jpg image, 442 of 4000 images
# Extract SIFT of 1398.jpg image, 443 of 4000 images
# Extract SIFT of 1399.jpg image, 444 of 4000 images
# Extract SIFT of 14.jpg image, 445 of 4000 images
# Extract SIFT of 140.jpg image, 446 of 4000 images
# Extract SIFT of 1400.jpg image, 447 of 4000 images
# Extract SIFT of 1401.jpg image, 448 of 4000 images
# Extract SIFT of 1402.jpg image, 449 of 4000 images
# Extract SIFT of 1403.jpg image, 450 of 4000 images
# Extract SIFT of 1404.jpg image, 451 of 4000 images
# Extract SIFT of 1405.jpg image, 452 of 4000 images
# Extract SIFT of 1406.jpg image, 453 of 4000 images
# Extract SIFT of 1407.jpg image, 454 of 4000 images
# Extract SIFT of 1408.jpg image, 455 of 4000 images
# Extract SIFT of 1409.jpg image, 456 of 4000 images
# Extract SIFT of 141.jpg image, 457 of 4000 images
# Extract SIFT of 1410.jpg image, 458 of 4000 images
# Extract SIFT of 1411.jpg image, 459 of 4000 images
# Extract SIFT of 1412.jpg image, 460 of 4000 images
# Extract SIFT of 1413.jpg image, 461 of 4000 images
# Extract SIFT of 1414.jpg image, 462 of 4000 images
# Extract SIFT of 1415.jpg image, 463 of 4000 images
# Extract SIFT of 1416.jpg image, 464 of 4000 images
# Extract SIFT of 1417.jpg image, 465 of 4000 images
# Extract SIFT of 1418.jpg image, 466 of 4000 images
# Extract SIFT of 1419.jpg image, 467 of 4000 images
# Extract SIFT of 142.jpg image, 468 of 4000 images
# Extract SIFT of 1420.jpg image, 469 of 4000 images
# Extract SIFT of 1421.jpg image, 470 of 4000 images
# Extract SIFT of 1422.jpg image, 471 of 4000 images
# Extract SIFT of 1423.jpg image, 472 of 4000 images
# Extract SIFT of 1424.jpg image, 473 of 4000 images
# Extract SIFT of 1425.jpg image, 474 of 4000 images
# Extract SIFT of 1426.jpg image, 475 of 4000 images
# Extract SIFT of 1427.jpg image, 476 of 4000 images
# Extract SIFT of 1428.jpg image, 477 of 4000 images
# Extract SIFT of 1429.jpg image, 478 of 4000 images
# Extract SIFT of 143.jpg image, 479 of 4000 images
# Extract SIFT of 1430.jpg image, 480 of 4000 images
# Extract SIFT of 1431.jpg image, 481 of 4000 images
# Extract SIFT of 1432.jpg image, 482 of 4000 images
# Extract SIFT of 1433.jpg image, 483 of 4000 images
# Extract SIFT of 1434.jpg image, 484 of 4000 images
# Extract SIFT of 1435.jpg image, 485 of 4000 images
# Extract SIFT of 1436.jpg image, 486 of 4000 images
# Extract SIFT of 1437.jpg image, 487 of 4000 images
# Extract SIFT of 1438.jpg image, 488 of 4000 images
# Extract SIFT of 1439.jpg image, 489 of 4000 images
# Extract SIFT of 144.jpg image, 490 of 4000 images
# Extract SIFT of 1440.jpg image, 491 of 4000 images
# Extract SIFT of 1441.jpg image, 492 of 4000 images
# Extract SIFT of 1442.jpg image, 493 of 4000 images
# Extract SIFT of 1443.jpg image, 494 of 4000 images
# Extract SIFT of 1444.jpg image, 495 of 4000 images
# Extract SIFT of 1445.jpg image, 496 of 4000 images
# Extract SIFT of 1446.jpg image, 497 of 4000 images
# Extract SIFT of 1447.jpg image, 498 of 4000 images
# Extract SIFT of 1448.jpg image, 499 of 4000 images
# Extract SIFT of 1449.jpg image, 500 of 4000 images
# Extract SIFT of 145.jpg image, 501 of 4000 images
# Extract SIFT of 1450.jpg image, 502 of 4000 images
# Extract SIFT of 1451.jpg image, 503 of 4000 images
# Extract SIFT of 1452.jpg image, 504 of 4000 images
# Extract SIFT of 1453.jpg image, 505 of 4000 images
# Extract SIFT of 1454.jpg image, 506 of 4000 images
# Extract SIFT of 1455.jpg image, 507 of 4000 images
# Extract SIFT of 1456.jpg image, 508 of 4000 images
# Extract SIFT of 1457.jpg image, 509 of 4000 images
# Extract SIFT of 1458.jpg image, 510 of 4000 images
# Extract SIFT of 1459.jpg image, 511 of 4000 images
# Extract SIFT of 146.jpg image, 512 of 4000 images
# Extract SIFT of 1460.jpg image, 513 of 4000 images
# Extract SIFT of 1461.jpg image, 514 of 4000 images
# Extract SIFT of 1462.jpg image, 515 of 4000 images
# Extract SIFT of 1463.jpg image, 516 of 4000 images
# Extract SIFT of 1464.jpg image, 517 of 4000 images
# Extract SIFT of 1465.jpg image, 518 of 4000 images
# Extract SIFT of 1466.jpg image, 519 of 4000 images
# Extract SIFT of 1467.jpg image, 520 of 4000 images
# Extract SIFT of 1468.jpg image, 521 of 4000 images
# Extract SIFT of 1469.jpg image, 522 of 4000 images
# Extract SIFT of 147.jpg image, 523 of 4000 images
# Extract SIFT of 1470.jpg image, 524 of 4000 images
# Extract SIFT of 1471.jpg image, 525 of 4000 images
# Extract SIFT of 1472.jpg image, 526 of 4000 images
# Extract SIFT of 1473.jpg image, 527 of 4000 images
# Extract SIFT of 1474.jpg image, 528 of 4000 images
# Extract SIFT of 1475.jpg image, 529 of 4000 images
# Extract SIFT of 1476.jpg image, 530 of 4000 images
# Extract SIFT of 1477.jpg image, 531 of 4000 images
# Extract SIFT of 1478.jpg image, 532 of 4000 images
# Extract SIFT of 1479.jpg image, 533 of 4000 images
# Extract SIFT of 148.jpg image, 534 of 4000 images
# Extract SIFT of 1480.jpg image, 535 of 4000 images
# Extract SIFT of 1481.jpg image, 536 of 4000 images
# Extract SIFT of 1482.jpg image, 537 of 4000 images
# Extract SIFT of 1483.jpg image, 538 of 4000 images
# Extract SIFT of 1484.jpg image, 539 of 4000 images
# Extract SIFT of 1485.jpg image, 540 of 4000 images
# Extract SIFT of 1486.jpg image, 541 of 4000 images
# Extract SIFT of 1487.jpg image, 542 of 4000 images
# Extract SIFT of 1488.jpg image, 543 of 4000 images
# Extract SIFT of 1489.jpg image, 544 of 4000 images
# Extract SIFT of 149.jpg image, 545 of 4000 images
# Extract SIFT of 1490.jpg image, 546 of 4000 images
# Extract SIFT of 1491.jpg image, 547 of 4000 images
# Extract SIFT of 1492.jpg image, 548 of 4000 images
# Extract SIFT of 1493.jpg image, 549 of 4000 images
# Extract SIFT of 1494.jpg image, 550 of 4000 images
# Extract SIFT of 1495.jpg image, 551 of 4000 images
# Extract SIFT of 1496.jpg image, 552 of 4000 images
# Extract SIFT of 1497.jpg image, 553 of 4000 images
# Extract SIFT of 1498.jpg image, 554 of 4000 images
# Extract SIFT of 1499.jpg image, 555 of 4000 images
# Extract SIFT of 15.jpg image, 556 of 4000 images
# Extract SIFT of 150.jpg image, 557 of 4000 images
# Extract SIFT of 1500.jpg image, 558 of 4000 images
# Extract SIFT of 1501.jpg image, 559 of 4000 images
# Extract SIFT of 1502.jpg image, 560 of 4000 images
# Extract SIFT of 1503.jpg image, 561 of 4000 images
# Extract SIFT of 1504.jpg image, 562 of 4000 images
# Extract SIFT of 1505.jpg image, 563 of 4000 images
# Extract SIFT of 1506.jpg image, 564 of 4000 images
# Extract SIFT of 1507.jpg image, 565 of 4000 images
# Extract SIFT of 1508.jpg image, 566 of 4000 images
# Extract SIFT of 1509.jpg image, 567 of 4000 images
# Extract SIFT of 151.jpg image, 568 of 4000 images
# Extract SIFT of 1510.jpg image, 569 of 4000 images
# Extract SIFT of 1511.jpg image, 570 of 4000 images
# Extract SIFT of 1512.jpg image, 571 of 4000 images
# Extract SIFT of 1513.jpg image, 572 of 4000 images
# Extract SIFT of 1514.jpg image, 573 of 4000 images
# Extract SIFT of 1515.jpg image, 574 of 4000 images
# Extract SIFT of 1516.jpg image, 575 of 4000 images
# Extract SIFT of 1517.jpg image, 576 of 4000 images
# Extract SIFT of 1518.jpg image, 577 of 4000 images
# Extract SIFT of 1519.jpg image, 578 of 4000 images
# Extract SIFT of 152.jpg image, 579 of 4000 images
# Extract SIFT of 1520.jpg image, 580 of 4000 images
# Extract SIFT of 1521.jpg image, 581 of 4000 images
# Extract SIFT of 1522.jpg image, 582 of 4000 images
# Extract SIFT of 1523.jpg image, 583 of 4000 images
# Extract SIFT of 1524.jpg image, 584 of 4000 images
# Extract SIFT of 1525.jpg image, 585 of 4000 images
# Extract SIFT of 1526.jpg image, 586 of 4000 images
# Extract SIFT of 1527.jpg image, 587 of 4000 images
# Extract SIFT of 1528.jpg image, 588 of 4000 images
# Extract SIFT of 1529.jpg image, 589 of 4000 images
# Extract SIFT of 153.jpg image, 590 of 4000 images
# Extract SIFT of 1530.jpg image, 591 of 4000 images
# Extract SIFT of 1531.jpg image, 592 of 4000 images
# Extract SIFT of 1532.jpg image, 593 of 4000 images
# Extract SIFT of 1533.jpg image, 594 of 4000 images
# Extract SIFT of 1534.jpg image, 595 of 4000 images
# Extract SIFT of 1535.jpg image, 596 of 4000 images
# Extract SIFT of 1536.jpg image, 597 of 4000 images
# Extract SIFT of 1537.jpg image, 598 of 4000 images
# Extract SIFT of 1538.jpg image, 599 of 4000 images
# Extract SIFT of 1539.jpg image, 600 of 4000 images
# Extract SIFT of 154.jpg image, 601 of 4000 images
# Extract SIFT of 1540.jpg image, 602 of 4000 images
# Extract SIFT of 1541.jpg image, 603 of 4000 images
# Extract SIFT of 1542.jpg image, 604 of 4000 images
# Extract SIFT of 1543.jpg image, 605 of 4000 images
# Extract SIFT of 1544.jpg image, 606 of 4000 images
# Extract SIFT of 1545.jpg image, 607 of 4000 images
# Extract SIFT of 1546.jpg image, 608 of 4000 images
# Extract SIFT of 1547.jpg image, 609 of 4000 images
# Extract SIFT of 1548.jpg image, 610 of 4000 images
# Extract SIFT of 1549.jpg image, 611 of 4000 images
# Extract SIFT of 155.jpg image, 612 of 4000 images
# Extract SIFT of 1550.jpg image, 613 of 4000 images
# Extract SIFT of 1551.jpg image, 614 of 4000 images
# Extract SIFT of 1552.jpg image, 615 of 4000 images
# Extract SIFT of 1553.jpg image, 616 of 4000 images
# Extract SIFT of 1554.jpg image, 617 of 4000 images
# Extract SIFT of 1555.jpg image, 618 of 4000 images
# Extract SIFT of 1556.jpg image, 619 of 4000 images
# Extract SIFT of 1557.jpg image, 620 of 4000 images
# Extract SIFT of 1558.jpg image, 621 of 4000 images
# Extract SIFT of 1559.jpg image, 622 of 4000 images
# Extract SIFT of 156.jpg image, 623 of 4000 images
# Extract SIFT of 1560.jpg image, 624 of 4000 images
# Extract SIFT of 1561.jpg image, 625 of 4000 images
# Extract SIFT of 1562.jpg image, 626 of 4000 images
# Extract SIFT of 1563.jpg image, 627 of 4000 images
# Extract SIFT of 1564.jpg image, 628 of 4000 images
# Extract SIFT of 1565.jpg image, 629 of 4000 images
# Extract SIFT of 1566.jpg image, 630 of 4000 images
# Extract SIFT of 1567.jpg image, 631 of 4000 images
# Extract SIFT of 1568.jpg image, 632 of 4000 images
# Extract SIFT of 1569.jpg image, 633 of 4000 images
# Extract SIFT of 157.jpg image, 634 of 4000 images
# Extract SIFT of 1570.jpg image, 635 of 4000 images
# Extract SIFT of 1571.jpg image, 636 of 4000 images
# Extract SIFT of 1572.jpg image, 637 of 4000 images
# Extract SIFT of 1573.jpg image, 638 of 4000 images
# Extract SIFT of 1574.jpg image, 639 of 4000 images
# Extract SIFT of 1575.jpg image, 640 of 4000 images
# Extract SIFT of 1576.jpg image, 641 of 4000 images
# Extract SIFT of 1577.jpg image, 642 of 4000 images
# Extract SIFT of 1578.jpg image, 643 of 4000 images
# Extract SIFT of 1579.jpg image, 644 of 4000 images
# Extract SIFT of 158.jpg image, 645 of 4000 images
# Extract SIFT of 1580.jpg image, 646 of 4000 images
# Extract SIFT of 1581.jpg image, 647 of 4000 images
# Extract SIFT of 1582.jpg image, 648 of 4000 images
# Extract SIFT of 1583.jpg image, 649 of 4000 images
# Extract SIFT of 1584.jpg image, 650 of 4000 images
# Extract SIFT of 1585.jpg image, 651 of 4000 images
# Extract SIFT of 1586.jpg image, 652 of 4000 images
# Extract SIFT of 1587.jpg image, 653 of 4000 images
# Extract SIFT of 1588.jpg image, 654 of 4000 images
# Extract SIFT of 1589.jpg image, 655 of 4000 images
# Extract SIFT of 159.jpg image, 656 of 4000 images
# Extract SIFT of 1590.jpg image, 657 of 4000 images
# Extract SIFT of 1591.jpg image, 658 of 4000 images
# Extract SIFT of 1592.jpg image, 659 of 4000 images
# Extract SIFT of 1593.jpg image, 660 of 4000 images
# Extract SIFT of 1594.jpg image, 661 of 4000 images
# Extract SIFT of 1595.jpg image, 662 of 4000 images
# Extract SIFT of 1596.jpg image, 663 of 4000 images
# Extract SIFT of 1597.jpg image, 664 of 4000 images
# Extract SIFT of 1598.jpg image, 665 of 4000 images
# Extract SIFT of 1599.jpg image, 666 of 4000 images
# Extract SIFT of 16.jpg image, 667 of 4000 images
# Extract SIFT of 160.jpg image, 668 of 4000 images
# Extract SIFT of 1600.jpg image, 669 of 4000 images
# Extract SIFT of 1601.jpg image, 670 of 4000 images
# Extract SIFT of 1602.jpg image, 671 of 4000 images
# Extract SIFT of 1603.jpg image, 672 of 4000 images
# Extract SIFT of 1604.jpg image, 673 of 4000 images
# Extract SIFT of 1605.jpg image, 674 of 4000 images
# Extract SIFT of 1606.jpg image, 675 of 4000 images
# Extract SIFT of 1607.jpg image, 676 of 4000 images
# Extract SIFT of 1608.jpg image, 677 of 4000 images
# Extract SIFT of 1609.jpg image, 678 of 4000 images
# Extract SIFT of 161.jpg image, 679 of 4000 images
# Extract SIFT of 1610.jpg image, 680 of 4000 images
# Extract SIFT of 1611.jpg image, 681 of 4000 images
# Extract SIFT of 1612.jpg image, 682 of 4000 images
# Extract SIFT of 1613.jpg image, 683 of 4000 images
# Extract SIFT of 1614.jpg image, 684 of 4000 images
# Extract SIFT of 1615.jpg image, 685 of 4000 images
# Extract SIFT of 1616.jpg image, 686 of 4000 images
# Extract SIFT of 1617.jpg image, 687 of 4000 images
# Extract SIFT of 1618.jpg image, 688 of 4000 images
# Extract SIFT of 1619.jpg image, 689 of 4000 images
# Extract SIFT of 162.jpg image, 690 of 4000 images
# Extract SIFT of 1620.jpg image, 691 of 4000 images
# Extract SIFT of 1621.jpg image, 692 of 4000 images
# Extract SIFT of 1622.jpg image, 693 of 4000 images
# Extract SIFT of 1623.jpg image, 694 of 4000 images
# Extract SIFT of 1624.jpg image, 695 of 4000 images
# Extract SIFT of 1625.jpg image, 696 of 4000 images
# Extract SIFT of 1626.jpg image, 697 of 4000 images
# Extract SIFT of 1627.jpg image, 698 of 4000 images
# Extract SIFT of 1628.jpg image, 699 of 4000 images
# Extract SIFT of 1629.jpg image, 700 of 4000 images
# Extract SIFT of 163.jpg image, 701 of 4000 images
# Extract SIFT of 1630.jpg image, 702 of 4000 images
# Extract SIFT of 1631.jpg image, 703 of 4000 images
# Extract SIFT of 1632.jpg image, 704 of 4000 images
# Extract SIFT of 1633.jpg image, 705 of 4000 images
# Extract SIFT of 1634.jpg image, 706 of 4000 images
# Extract SIFT of 1635.jpg image, 707 of 4000 images
# Extract SIFT of 1636.jpg image, 708 of 4000 images
# Extract SIFT of 1637.jpg image, 709 of 4000 images
# Extract SIFT of 1638.jpg image, 710 of 4000 images
# Extract SIFT of 1639.jpg image, 711 of 4000 images
# Extract SIFT of 164.jpg image, 712 of 4000 images
# Extract SIFT of 1640.jpg image, 713 of 4000 images
# Extract SIFT of 1641.jpg image, 714 of 4000 images
# Extract SIFT of 1642.jpg image, 715 of 4000 images
# Extract SIFT of 1643.jpg image, 716 of 4000 images
# Extract SIFT of 1644.jpg image, 717 of 4000 images
# Extract SIFT of 1645.jpg image, 718 of 4000 images
# Extract SIFT of 1646.jpg image, 719 of 4000 images
# Extract SIFT of 1647.jpg image, 720 of 4000 images
# Extract SIFT of 1648.jpg image, 721 of 4000 images
# Extract SIFT of 1649.jpg image, 722 of 4000 images
# Extract SIFT of 165.jpg image, 723 of 4000 images
# Extract SIFT of 1650.jpg image, 724 of 4000 images
# Extract SIFT of 1651.jpg image, 725 of 4000 images
# Extract SIFT of 1652.jpg image, 726 of 4000 images
# Extract SIFT of 1653.jpg image, 727 of 4000 images
# Extract SIFT of 1654.jpg image, 728 of 4000 images
# Extract SIFT of 1655.jpg image, 729 of 4000 images
# Extract SIFT of 1656.jpg image, 730 of 4000 images
# Extract SIFT of 1657.jpg image, 731 of 4000 images
# Extract SIFT of 1658.jpg image, 732 of 4000 images
# Extract SIFT of 1659.jpg image, 733 of 4000 images
# Extract SIFT of 166.jpg image, 734 of 4000 images
# Extract SIFT of 1660.jpg image, 735 of 4000 images
# Extract SIFT of 1661.jpg image, 736 of 4000 images
# Extract SIFT of 1662.jpg image, 737 of 4000 images
# Extract SIFT of 1663.jpg image, 738 of 4000 images
# Extract SIFT of 1664.jpg image, 739 of 4000 images
# Extract SIFT of 1665.jpg image, 740 of 4000 images
# Extract SIFT of 1666.jpg image, 741 of 4000 images
# Extract SIFT of 1667.jpg image, 742 of 4000 images
# Extract SIFT of 1668.jpg image, 743 of 4000 images
# Extract SIFT of 1669.jpg image, 744 of 4000 images
# Extract SIFT of 167.jpg image, 745 of 4000 images
# Extract SIFT of 1670.jpg image, 746 of 4000 images
# Extract SIFT of 1671.jpg image, 747 of 4000 images
# Extract SIFT of 1672.jpg image, 748 of 4000 images
# Extract SIFT of 1673.jpg image, 749 of 4000 images
# Extract SIFT of 1674.jpg image, 750 of 4000 images
# Extract SIFT of 1675.jpg image, 751 of 4000 images
# Extract SIFT of 1676.jpg image, 752 of 4000 images
# Extract SIFT of 1677.jpg image, 753 of 4000 images
# Extract SIFT of 1678.jpg image, 754 of 4000 images
# Extract SIFT of 1679.jpg image, 755 of 4000 images
# Extract SIFT of 168.jpg image, 756 of 4000 images
# Extract SIFT of 1680.jpg image, 757 of 4000 images
# Extract SIFT of 1681.jpg image, 758 of 4000 images
# Extract SIFT of 1682.jpg image, 759 of 4000 images
# Extract SIFT of 1683.jpg image, 760 of 4000 images
# Extract SIFT of 1684.jpg image, 761 of 4000 images
# Extract SIFT of 1685.jpg image, 762 of 4000 images
# Extract SIFT of 1686.jpg image, 763 of 4000 images
# Extract SIFT of 1687.jpg image, 764 of 4000 images
# Extract SIFT of 1688.jpg image, 765 of 4000 images
# Extract SIFT of 1689.jpg image, 766 of 4000 images
# Extract SIFT of 169.jpg image, 767 of 4000 images
# Extract SIFT of 1690.jpg image, 768 of 4000 images
# Extract SIFT of 1691.jpg image, 769 of 4000 images
# Extract SIFT of 1692.jpg image, 770 of 4000 images
# Extract SIFT of 1693.jpg image, 771 of 4000 images
# Extract SIFT of 1694.jpg image, 772 of 4000 images
# Extract SIFT of 1695.jpg image, 773 of 4000 images
# Extract SIFT of 1696.jpg image, 774 of 4000 images
# Extract SIFT of 1697.jpg image, 775 of 4000 images
# Extract SIFT of 1698.jpg image, 776 of 4000 images
# Extract SIFT of 1699.jpg image, 777 of 4000 images
# Extract SIFT of 17.jpg image, 778 of 4000 images
# Extract SIFT of 170.jpg image, 779 of 4000 images
# Extract SIFT of 1700.jpg image, 780 of 4000 images
# Extract SIFT of 1701.jpg image, 781 of 4000 images
# Extract SIFT of 1702.jpg image, 782 of 4000 images
# Extract SIFT of 1703.jpg image, 783 of 4000 images
# Extract SIFT of 1704.jpg image, 784 of 4000 images
# Extract SIFT of 1705.jpg image, 785 of 4000 images
# Extract SIFT of 1706.jpg image, 786 of 4000 images
# Extract SIFT of 1707.jpg image, 787 of 4000 images
# Extract SIFT of 1708.jpg image, 788 of 4000 images
# Extract SIFT of 1709.jpg image, 789 of 4000 images
# Extract SIFT of 171.jpg image, 790 of 4000 images
# Extract SIFT of 1710.jpg image, 791 of 4000 images
# Extract SIFT of 1711.jpg image, 792 of 4000 images
# Extract SIFT of 1712.jpg image, 793 of 4000 images
# Extract SIFT of 1713.jpg image, 794 of 4000 images
# Extract SIFT of 1714.jpg image, 795 of 4000 images
# Extract SIFT of 1715.jpg image, 796 of 4000 images
# Extract SIFT of 1716.jpg image, 797 of 4000 images
# Extract SIFT of 1717.jpg image, 798 of 4000 images
# Extract SIFT of 1718.jpg image, 799 of 4000 images
# Extract SIFT of 1719.jpg image, 800 of 4000 images
# Extract SIFT of 172.jpg image, 801 of 4000 images
# Extract SIFT of 1720.jpg image, 802 of 4000 images
# Extract SIFT of 1721.jpg image, 803 of 4000 images
# Extract SIFT of 1722.jpg image, 804 of 4000 images
# Extract SIFT of 1723.jpg image, 805 of 4000 images
# Extract SIFT of 1724.jpg image, 806 of 4000 images
# Extract SIFT of 1725.jpg image, 807 of 4000 images
# Extract SIFT of 1726.jpg image, 808 of 4000 images
# Extract SIFT of 1727.jpg image, 809 of 4000 images
# Extract SIFT of 1728.jpg image, 810 of 4000 images
# Extract SIFT of 1729.jpg image, 811 of 4000 images
# Extract SIFT of 173.jpg image, 812 of 4000 images
# Extract SIFT of 1730.jpg image, 813 of 4000 images
# Extract SIFT of 1731.jpg image, 814 of 4000 images
# Extract SIFT of 1732.jpg image, 815 of 4000 images
# Extract SIFT of 1733.jpg image, 816 of 4000 images
# Extract SIFT of 1734.jpg image, 817 of 4000 images
# Extract SIFT of 1735.jpg image, 818 of 4000 images
# Extract SIFT of 1736.jpg image, 819 of 4000 images
# Extract SIFT of 1737.jpg image, 820 of 4000 images
# Extract SIFT of 1738.jpg image, 821 of 4000 images
# Extract SIFT of 1739.jpg image, 822 of 4000 images
# Extract SIFT of 174.jpg image, 823 of 4000 images
# Extract SIFT of 1740.jpg image, 824 of 4000 images
# Extract SIFT of 1741.jpg image, 825 of 4000 images
# Extract SIFT of 1742.jpg image, 826 of 4000 images
# Extract SIFT of 1743.jpg image, 827 of 4000 images
# Extract SIFT of 1744.jpg image, 828 of 4000 images
# Extract SIFT of 1745.jpg image, 829 of 4000 images
# Extract SIFT of 1746.jpg image, 830 of 4000 images
# Extract SIFT of 1747.jpg image, 831 of 4000 images
# Extract SIFT of 1748.jpg image, 832 of 4000 images
# Extract SIFT of 1749.jpg image, 833 of 4000 images
# Extract SIFT of 175.jpg image, 834 of 4000 images
# Extract SIFT of 1750.jpg image, 835 of 4000 images
# Extract SIFT of 1751.jpg image, 836 of 4000 images
# Extract SIFT of 1752.jpg image, 837 of 4000 images
# Extract SIFT of 1753.jpg image, 838 of 4000 images
# Extract SIFT of 1754.jpg image, 839 of 4000 images
# Extract SIFT of 1755.jpg image, 840 of 4000 images
# Extract SIFT of 1756.jpg image, 841 of 4000 images
# Extract SIFT of 1757.jpg image, 842 of 4000 images
# Extract SIFT of 1758.jpg image, 843 of 4000 images
# Extract SIFT of 1759.jpg image, 844 of 4000 images
# Extract SIFT of 176.jpg image, 845 of 4000 images
# Extract SIFT of 1760.jpg image, 846 of 4000 images
# Extract SIFT of 1761.jpg image, 847 of 4000 images
# Extract SIFT of 1762.jpg image, 848 of 4000 images
# Extract SIFT of 1763.jpg image, 849 of 4000 images
# Extract SIFT of 1764.jpg image, 850 of 4000 images
# Extract SIFT of 1765.jpg image, 851 of 4000 images
# Extract SIFT of 1766.jpg image, 852 of 4000 images
# Extract SIFT of 1767.jpg image, 853 of 4000 images
# Extract SIFT of 1768.jpg image, 854 of 4000 images
# Extract SIFT of 1769.jpg image, 855 of 4000 images
# Extract SIFT of 177.jpg image, 856 of 4000 images
# Extract SIFT of 1770.jpg image, 857 of 4000 images
# Extract SIFT of 1771.jpg image, 858 of 4000 images
# Extract SIFT of 1772.jpg image, 859 of 4000 images
# Extract SIFT of 1773.jpg image, 860 of 4000 images
# Extract SIFT of 1774.jpg image, 861 of 4000 images
# Extract SIFT of 1775.jpg image, 862 of 4000 images
# Extract SIFT of 1776.jpg image, 863 of 4000 images
# Extract SIFT of 1777.jpg image, 864 of 4000 images
# Extract SIFT of 1778.jpg image, 865 of 4000 images
# Extract SIFT of 1779.jpg image, 866 of 4000 images
# Extract SIFT of 178.jpg image, 867 of 4000 images
# Extract SIFT of 1780.jpg image, 868 of 4000 images
# Extract SIFT of 1781.jpg image, 869 of 4000 images
# Extract SIFT of 1782.jpg image, 870 of 4000 images
# Extract SIFT of 1783.jpg image, 871 of 4000 images
# Extract SIFT of 1784.jpg image, 872 of 4000 images
# Extract SIFT of 1785.jpg image, 873 of 4000 images
# Extract SIFT of 1786.jpg image, 874 of 4000 images
# Extract SIFT of 1787.jpg image, 875 of 4000 images
# Extract SIFT of 1788.jpg image, 876 of 4000 images
# Extract SIFT of 1789.jpg image, 877 of 4000 images
# Extract SIFT of 179.jpg image, 878 of 4000 images
# Extract SIFT of 1790.jpg image, 879 of 4000 images
# Extract SIFT of 1791.jpg image, 880 of 4000 images
# Extract SIFT of 1792.jpg image, 881 of 4000 images
# Extract SIFT of 1793.jpg image, 882 of 4000 images
# Extract SIFT of 1794.jpg image, 883 of 4000 images
# Extract SIFT of 1795.jpg image, 884 of 4000 images
# Extract SIFT of 1796.jpg image, 885 of 4000 images
# Extract SIFT of 1797.jpg image, 886 of 4000 images
# Extract SIFT of 1798.jpg image, 887 of 4000 images
# Extract SIFT of 1799.jpg image, 888 of 4000 images
# Extract SIFT of 18.jpg image, 889 of 4000 images
# Extract SIFT of 180.jpg image, 890 of 4000 images
# Extract SIFT of 1800.jpg image, 891 of 4000 images
# Extract SIFT of 1801.jpg image, 892 of 4000 images
# Extract SIFT of 1802.jpg image, 893 of 4000 images
# Extract SIFT of 1803.jpg image, 894 of 4000 images
# Extract SIFT of 1804.jpg image, 895 of 4000 images
# Extract SIFT of 1805.jpg image, 896 of 4000 images
# Extract SIFT of 1806.jpg image, 897 of 4000 images
# Extract SIFT of 1807.jpg image, 898 of 4000 images
# Extract SIFT of 1808.jpg image, 899 of 4000 images
# Extract SIFT of 1809.jpg image, 900 of 4000 images
# Extract SIFT of 181.jpg image, 901 of 4000 images
# Extract SIFT of 1810.jpg image, 902 of 4000 images
# Extract SIFT of 1811.jpg image, 903 of 4000 images
# Extract SIFT of 1812.jpg image, 904 of 4000 images
# Extract SIFT of 1813.jpg image, 905 of 4000 images
# Extract SIFT of 1814.jpg image, 906 of 4000 images
# Extract SIFT of 1815.jpg image, 907 of 4000 images
# Extract SIFT of 1816.jpg image, 908 of 4000 images
# Extract SIFT of 1817.jpg image, 909 of 4000 images
# Extract SIFT of 1818.jpg image, 910 of 4000 images
# Extract SIFT of 1819.jpg image, 911 of 4000 images
# Extract SIFT of 182.jpg image, 912 of 4000 images
# Extract SIFT of 1820.jpg image, 913 of 4000 images
# Extract SIFT of 1821.jpg image, 914 of 4000 images
# Extract SIFT of 1822.jpg image, 915 of 4000 images
# Extract SIFT of 1823.jpg image, 916 of 4000 images
# Extract SIFT of 1824.jpg image, 917 of 4000 images
# Extract SIFT of 1825.jpg image, 918 of 4000 images
# Extract SIFT of 1826.jpg image, 919 of 4000 images
# Extract SIFT of 1827.jpg image, 920 of 4000 images
# Extract SIFT of 1828.jpg image, 921 of 4000 images
# Extract SIFT of 1829.jpg image, 922 of 4000 images
# Extract SIFT of 183.jpg image, 923 of 4000 images
# Extract SIFT of 1830.jpg image, 924 of 4000 images
# Extract SIFT of 1831.jpg image, 925 of 4000 images
# Extract SIFT of 1832.jpg image, 926 of 4000 images
# Extract SIFT of 1833.jpg image, 927 of 4000 images
# Extract SIFT of 1834.jpg image, 928 of 4000 images
# Extract SIFT of 1835.jpg image, 929 of 4000 images
# Extract SIFT of 1836.jpg image, 930 of 4000 images
# Extract SIFT of 1837.jpg image, 931 of 4000 images
# Extract SIFT of 1838.jpg image, 932 of 4000 images
# Extract SIFT of 1839.jpg image, 933 of 4000 images
# Extract SIFT of 184.jpg image, 934 of 4000 images
# Extract SIFT of 1840.jpg image, 935 of 4000 images
# Extract SIFT of 1841.jpg image, 936 of 4000 images
# Extract SIFT of 1842.jpg image, 937 of 4000 images
# Extract SIFT of 1843.jpg image, 938 of 4000 images
# Extract SIFT of 1844.jpg image, 939 of 4000 images
# Extract SIFT of 1845.jpg image, 940 of 4000 images
# Extract SIFT of 1846.jpg image, 941 of 4000 images
# Extract SIFT of 1847.jpg image, 942 of 4000 images
# Extract SIFT of 1848.jpg image, 943 of 4000 images
# Extract SIFT of 1849.jpg image, 944 of 4000 images
# ...
# Extract SIFT of 716.jpg image, 3686 of 4000 images
# Extract SIFT of 717.jpg image, 3687 of 4000 images
# Extract SIFT of 718.jpg image, 3688 of 4000 images
# Extract SIFT of 719.jpg image, 3689 of 4000 images
# Extract SIFT of 72.jpg image, 3690 of 4000 images
# Extract SIFT of 720.jpg image, 3691 of 4000 images
# Extract SIFT of 721.jpg image, 3692 of 4000 images
# Extract SIFT of 722.jpg image, 3693 of 4000 images
# Extract SIFT of 723.jpg image, 3694 of 4000 images
# Extract SIFT of 724.jpg image, 3695 of 4000 images
# Extract SIFT of 725.jpg image, 3696 of 4000 images
# Extract SIFT of 726.jpg image, 3697 of 4000 images
# Extract SIFT of 727.jpg image, 3698 of 4000 images
# Extract SIFT of 728.jpg image, 3699 of 4000 images
# Extract SIFT of 729.jpg image, 3700 of 4000 images
# Extract SIFT of 73.jpg image, 3701 of 4000 images
# Extract SIFT of 730.jpg image, 3702 of 4000 images
# Extract SIFT of 731.jpg image, 3703 of 4000 images
# Extract SIFT of 732.jpg image, 3704 of 4000 images
# Extract SIFT of 733.jpg image, 3705 of 4000 images
# Extract SIFT of 734.jpg image, 3706 of 4000 images
# Extract SIFT of 735.jpg image, 3707 of 4000 images
# Extract SIFT of 736.jpg image, 3708 of 4000 images
# Extract SIFT of 737.jpg image, 3709 of 4000 images
# Extract SIFT of 738.jpg image, 3710 of 4000 images
# Extract SIFT of 739.jpg image, 3711 of 4000 images
# Extract SIFT of 74.jpg image, 3712 of 4000 images
# Extract SIFT of 740.jpg image, 3713 of 4000 images
# Extract SIFT of 741.jpg image, 3714 of 4000 images
# Extract SIFT of 742.jpg image, 3715 of 4000 images
# Extract SIFT of 743.jpg image, 3716 of 4000 images
# Extract SIFT of 744.jpg image, 3717 of 4000 images
# Extract SIFT of 745.jpg image, 3718 of 4000 images
# Extract SIFT of 746.jpg image, 3719 of 4000 images
# Extract SIFT of 747.jpg image, 3720 of 4000 images
# Extract SIFT of 748.jpg image, 3721 of 4000 images
# Extract SIFT of 749.jpg image, 3722 of 4000 images
# Extract SIFT of 75.jpg image, 3723 of 4000 images
# Extract SIFT of 750.jpg image, 3724 of 4000 images
# Extract SIFT of 751.jpg image, 3725 of 4000 images
# Extract SIFT of 752.jpg image, 3726 of 4000 images
# Extract SIFT of 753.jpg image, 3727 of 4000 images
# Extract SIFT of 754.jpg image, 3728 of 4000 images
# Extract SIFT of 755.jpg image, 3729 of 4000 images
# Extract SIFT of 756.jpg image, 3730 of 4000 images
# Extract SIFT of 757.jpg image, 3731 of 4000 images
# Extract SIFT of 758.jpg image, 3732 of 4000 images
# Extract SIFT of 759.jpg image, 3733 of 4000 images
# Extract SIFT of 76.jpg image, 3734 of 4000 images
# Extract SIFT of 760.jpg image, 3735 of 4000 images
# Extract SIFT of 761.jpg image, 3736 of 4000 images
# Extract SIFT of 762.jpg image, 3737 of 4000 images
# Extract SIFT of 763.jpg image, 3738 of 4000 images
# Extract SIFT of 764.jpg image, 3739 of 4000 images
# Extract SIFT of 765.jpg image, 3740 of 4000 images
# Extract SIFT of 766.jpg image, 3741 of 4000 images
# Extract SIFT of 767.jpg image, 3742 of 4000 images
# Extract SIFT of 768.jpg image, 3743 of 4000 images
# Extract SIFT of 769.jpg image, 3744 of 4000 images
# Extract SIFT of 77.jpg image, 3745 of 4000 images
# Extract SIFT of 770.jpg image, 3746 of 4000 images
# Extract SIFT of 771.jpg image, 3747 of 4000 images
# Extract SIFT of 772.jpg image, 3748 of 4000 images
# Extract SIFT of 773.jpg image, 3749 of 4000 images
# Extract SIFT of 774.jpg image, 3750 of 4000 images
# Extract SIFT of 775.jpg image, 3751 of 4000 images
# Extract SIFT of 776.jpg image, 3752 of 4000 images
# Extract SIFT of 777.jpg image, 3753 of 4000 images
# Extract SIFT of 778.jpg image, 3754 of 4000 images
# Extract SIFT of 779.jpg image, 3755 of 4000 images
# Extract SIFT of 78.jpg image, 3756 of 4000 images
# Extract SIFT of 780.jpg image, 3757 of 4000 images
# Extract SIFT of 781.jpg image, 3758 of 4000 images
# Extract SIFT of 782.jpg image, 3759 of 4000 images
# Extract SIFT of 783.jpg image, 3760 of 4000 images
# Extract SIFT of 784.jpg image, 3761 of 4000 images
# Extract SIFT of 785.jpg image, 3762 of 4000 images
# Extract SIFT of 786.jpg image, 3763 of 4000 images
# Extract SIFT of 787.jpg image, 3764 of 4000 images
# Extract SIFT of 788.jpg image, 3765 of 4000 images
# Extract SIFT of 789.jpg image, 3766 of 4000 images
# Extract SIFT of 79.jpg image, 3767 of 4000 images
# Extract SIFT of 790.jpg image, 3768 of 4000 images
# Extract SIFT of 791.jpg image, 3769 of 4000 images
# Extract SIFT of 792.jpg image, 3770 of 4000 images
# Extract SIFT of 793.jpg image, 3771 of 4000 images
# Extract SIFT of 794.jpg image, 3772 of 4000 images
# Extract SIFT of 795.jpg image, 3773 of 4000 images
# Extract SIFT of 796.jpg image, 3774 of 4000 images
# Extract SIFT of 797.jpg image, 3775 of 4000 images
# Extract SIFT of 798.jpg image, 3776 of 4000 images
# Extract SIFT of 799.jpg image, 3777 of 4000 images
# Extract SIFT of 8.jpg image, 3778 of 4000 images
# Extract SIFT of 80.jpg image, 3779 of 4000 images
# Extract SIFT of 800.jpg image, 3780 of 4000 images
# Extract SIFT of 801.jpg image, 3781 of 4000 images
# Extract SIFT of 802.jpg image, 3782 of 4000 images
# Extract SIFT of 803.jpg image, 3783 of 4000 images
# Extract SIFT of 804.jpg image, 3784 of 4000 images
# Extract SIFT of 805.jpg image, 3785 of 4000 images
# Extract SIFT of 806.jpg image, 3786 of 4000 images
# Extract SIFT of 807.jpg image, 3787 of 4000 images
# Extract SIFT of 808.jpg image, 3788 of 4000 images
# Extract SIFT of 809.jpg image, 3789 of 4000 images
# Extract SIFT of 81.jpg image, 3790 of 4000 images
# Extract SIFT of 810.jpg image, 3791 of 4000 images
# Extract SIFT of 811.jpg image, 3792 of 4000 images
# Extract SIFT of 812.jpg image, 3793 of 4000 images
# Extract SIFT of 813.jpg image, 3794 of 4000 images
# Extract SIFT of 814.jpg image, 3795 of 4000 images
# Extract SIFT of 815.jpg image, 3796 of 4000 images
# Extract SIFT of 816.jpg image, 3797 of 4000 images
# Extract SIFT of 817.jpg image, 3798 of 4000 images
# Extract SIFT of 818.jpg image, 3799 of 4000 images
# Extract SIFT of 819.jpg image, 3800 of 4000 images
# Extract SIFT of 82.jpg image, 3801 of 4000 images
# Extract SIFT of 820.jpg image, 3802 of 4000 images
# Extract SIFT of 821.jpg image, 3803 of 4000 images
# Extract SIFT of 822.jpg image, 3804 of 4000 images
# Extract SIFT of 823.jpg image, 3805 of 4000 images
# Extract SIFT of 824.jpg image, 3806 of 4000 images
# Extract SIFT of 825.jpg image, 3807 of 4000 images
# Extract SIFT of 826.jpg image, 3808 of 4000 images
# Extract SIFT of 827.jpg image, 3809 of 4000 images
# Extract SIFT of 828.jpg image, 3810 of 4000 images
# Extract SIFT of 829.jpg image, 3811 of 4000 images
# Extract SIFT of 83.jpg image, 3812 of 4000 images
# Extract SIFT of 830.jpg image, 3813 of 4000 images
# Extract SIFT of 831.jpg image, 3814 of 4000 images
# Extract SIFT of 832.jpg image, 3815 of 4000 images
# Extract SIFT of 833.jpg image, 3816 of 4000 images
# Extract SIFT of 834.jpg image, 3817 of 4000 images
# Extract SIFT of 835.jpg image, 3818 of 4000 images
# Extract SIFT of 836.jpg image, 3819 of 4000 images
# Extract SIFT of 837.jpg image, 3820 of 4000 images
# Extract SIFT of 838.jpg image, 3821 of 4000 images
# Extract SIFT of 839.jpg image, 3822 of 4000 images
# Extract SIFT of 84.jpg image, 3823 of 4000 images
# Extract SIFT of 840.jpg image, 3824 of 4000 images
# Extract SIFT of 841.jpg image, 3825 of 4000 images
# Extract SIFT of 842.jpg image, 3826 of 4000 images
# Extract SIFT of 843.jpg image, 3827 of 4000 images
# Extract SIFT of 844.jpg image, 3828 of 4000 images
# Extract SIFT of 845.jpg image, 3829 of 4000 images
# Extract SIFT of 846.jpg image, 3830 of 4000 images
# Extract SIFT of 847.jpg image, 3831 of 4000 images
# Extract SIFT of 848.jpg image, 3832 of 4000 images
# Extract SIFT of 849.jpg image, 3833 of 4000 images
# Extract SIFT of 85.jpg image, 3834 of 4000 images
# Extract SIFT of 850.jpg image, 3835 of 4000 images
# Extract SIFT of 851.jpg image, 3836 of 4000 images
# Extract SIFT of 852.jpg image, 3837 of 4000 images
# Extract SIFT of 853.jpg image, 3838 of 4000 images
# Extract SIFT of 854.jpg image, 3839 of 4000 images
# Extract SIFT of 855.jpg image, 3840 of 4000 images
# Extract SIFT of 856.jpg image, 3841 of 4000 images
# Extract SIFT of 857.jpg image, 3842 of 4000 images
# Extract SIFT of 858.jpg image, 3843 of 4000 images
# Extract SIFT of 859.jpg image, 3844 of 4000 images
# Extract SIFT of 86.jpg image, 3845 of 4000 images
# Extract SIFT of 860.jpg image, 3846 of 4000 images
# Extract SIFT of 861.jpg image, 3847 of 4000 images
# Extract SIFT of 862.jpg image, 3848 of 4000 images
# Extract SIFT of 863.jpg image, 3849 of 4000 images
# Extract SIFT of 864.jpg image, 3850 of 4000 images
# Extract SIFT of 865.jpg image, 3851 of 4000 images
# Extract SIFT of 866.jpg image, 3852 of 4000 images
# Extract SIFT of 867.jpg image, 3853 of 4000 images
# Extract SIFT of 868.jpg image, 3854 of 4000 images
# Extract SIFT of 869.jpg image, 3855 of 4000 images
# Extract SIFT of 87.jpg image, 3856 of 4000 images
# Extract SIFT of 870.jpg image, 3857 of 4000 images
# Extract SIFT of 871.jpg image, 3858 of 4000 images
# Extract SIFT of 872.jpg image, 3859 of 4000 images
# Extract SIFT of 873.jpg image, 3860 of 4000 images
# Extract SIFT of 874.jpg image, 3861 of 4000 images
# Extract SIFT of 875.jpg image, 3862 of 4000 images
# Extract SIFT of 876.jpg image, 3863 of 4000 images
# Extract SIFT of 877.jpg image, 3864 of 4000 images
# Extract SIFT of 878.jpg image, 3865 of 4000 images
# Extract SIFT of 879.jpg image, 3866 of 4000 images
# Extract SIFT of 88.jpg image, 3867 of 4000 images
# Extract SIFT of 880.jpg image, 3868 of 4000 images
# Extract SIFT of 881.jpg image, 3869 of 4000 images
# Extract SIFT of 882.jpg image, 3870 of 4000 images
# Extract SIFT of 883.jpg image, 3871 of 4000 images
# Extract SIFT of 884.jpg image, 3872 of 4000 images
# Extract SIFT of 885.jpg image, 3873 of 4000 images
# Extract SIFT of 886.jpg image, 3874 of 4000 images
# Extract SIFT of 887.jpg image, 3875 of 4000 images
# Extract SIFT of 888.jpg image, 3876 of 4000 images
# Extract SIFT of 889.jpg image, 3877 of 4000 images
# Extract SIFT of 89.jpg image, 3878 of 4000 images
# Extract SIFT of 890.jpg image, 3879 of 4000 images
# Extract SIFT of 891.jpg image, 3880 of 4000 images
# Extract SIFT of 892.jpg image, 3881 of 4000 images
# Extract SIFT of 893.jpg image, 3882 of 4000 images
# Extract SIFT of 894.jpg image, 3883 of 4000 images
# Extract SIFT of 895.jpg image, 3884 of 4000 images
# Extract SIFT of 896.jpg image, 3885 of 4000 images
# Extract SIFT of 897.jpg image, 3886 of 4000 images
# Extract SIFT of 898.jpg image, 3887 of 4000 images
# Extract SIFT of 899.jpg image, 3888 of 4000 images
# Extract SIFT of 9.jpg image, 3889 of 4000 images
# Extract SIFT of 90.jpg image, 3890 of 4000 images
# Extract SIFT of 900.jpg image, 3891 of 4000 images
# Extract SIFT of 901.jpg image, 3892 of 4000 images
# Extract SIFT of 902.jpg image, 3893 of 4000 images
# Extract SIFT of 903.jpg image, 3894 of 4000 images
# Extract SIFT of 904.jpg image, 3895 of 4000 images
# Extract SIFT of 905.jpg image, 3896 of 4000 images
# Extract SIFT of 906.jpg image, 3897 of 4000 images
# Extract SIFT of 907.jpg image, 3898 of 4000 images
# Extract SIFT of 908.jpg image, 3899 of 4000 images
# Extract SIFT of 909.jpg image, 3900 of 4000 images
# Extract SIFT of 91.jpg image, 3901 of 4000 images
# Extract SIFT of 910.jpg image, 3902 of 4000 images
# Extract SIFT of 911.jpg image, 3903 of 4000 images
# Extract SIFT of 912.jpg image, 3904 of 4000 images
# Extract SIFT of 913.jpg image, 3905 of 4000 images
# Extract SIFT of 914.jpg image, 3906 of 4000 images
# Extract SIFT of 915.jpg image, 3907 of 4000 images
# Extract SIFT of 916.jpg image, 3908 of 4000 images
# Extract SIFT of 917.jpg image, 3909 of 4000 images
# Extract SIFT of 918.jpg image, 3910 of 4000 images
# Extract SIFT of 919.jpg image, 3911 of 4000 images
# Extract SIFT of 92.jpg image, 3912 of 4000 images
# Extract SIFT of 920.jpg image, 3913 of 4000 images
# Extract SIFT of 921.jpg image, 3914 of 4000 images
# Extract SIFT of 922.jpg image, 3915 of 4000 images
# Extract SIFT of 923.jpg image, 3916 of 4000 images
# Extract SIFT of 924.jpg image, 3917 of 4000 images
# Extract SIFT of 925.jpg image, 3918 of 4000 images
# Extract SIFT of 926.jpg image, 3919 of 4000 images
# Extract SIFT of 927.jpg image, 3920 of 4000 images
# Extract SIFT of 928.jpg image, 3921 of 4000 images
# Extract SIFT of 929.jpg image, 3922 of 4000 images
# Extract SIFT of 93.jpg image, 3923 of 4000 images
# Extract SIFT of 930.jpg image, 3924 of 4000 images
# Extract SIFT of 931.jpg image, 3925 of 4000 images
# Extract SIFT of 932.jpg image, 3926 of 4000 images
# Extract SIFT of 933.jpg image, 3927 of 4000 images
# Extract SIFT of 934.jpg image, 3928 of 4000 images
# Extract SIFT of 935.jpg image, 3929 of 4000 images
# Extract SIFT of 936.jpg image, 3930 of 4000 images
# Extract SIFT of 937.jpg image, 3931 of 4000 images
# Extract SIFT of 938.jpg image, 3932 of 4000 images
# Extract SIFT of 939.jpg image, 3933 of 4000 images
# Extract SIFT of 94.jpg image, 3934 of 4000 images
# Extract SIFT of 940.jpg image, 3935 of 4000 images
# Extract SIFT of 941.jpg image, 3936 of 4000 images
# Extract SIFT of 942.jpg image, 3937 of 4000 images
# Extract SIFT of 943.jpg image, 3938 of 4000 images
# Extract SIFT of 944.jpg image, 3939 of 4000 images
# Extract SIFT of 945.jpg image, 3940 of 4000 images
# Extract SIFT of 946.jpg image, 3941 of 4000 images
# Extract SIFT of 947.jpg image, 3942 of 4000 images
# Extract SIFT of 948.jpg image, 3943 of 4000 images
# Extract SIFT of 949.jpg image, 3944 of 4000 images
# Extract SIFT of 95.jpg image, 3945 of 4000 images
# Extract SIFT of 950.jpg image, 3946 of 4000 images
# Extract SIFT of 951.jpg image, 3947 of 4000 images
# Extract SIFT of 952.jpg image, 3948 of 4000 images
# Extract SIFT of 953.jpg image, 3949 of 4000 images
# Extract SIFT of 954.jpg image, 3950 of 4000 images
# Extract SIFT of 955.jpg image, 3951 of 4000 images
# Extract SIFT of 956.jpg image, 3952 of 4000 images
# Extract SIFT of 957.jpg image, 3953 of 4000 images
# Extract SIFT of 958.jpg image, 3954 of 4000 images
# Extract SIFT of 959.jpg image, 3955 of 4000 images
# Extract SIFT of 96.jpg image, 3956 of 4000 images
# Extract SIFT of 960.jpg image, 3957 of 4000 images
# Extract SIFT of 961.jpg image, 3958 of 4000 images
# Extract SIFT of 962.jpg image, 3959 of 4000 images
# Extract SIFT of 963.jpg image, 3960 of 4000 images
# Extract SIFT of 964.jpg image, 3961 of 4000 images
# Extract SIFT of 965.jpg image, 3962 of 4000 images
# Extract SIFT of 966.jpg image, 3963 of 4000 images
# Extract SIFT of 967.jpg image, 3964 of 4000 images
# Extract SIFT of 968.jpg image, 3965 of 4000 images
# Extract SIFT of 969.jpg image, 3966 of 4000 images
# Extract SIFT of 97.jpg image, 3967 of 4000 images
# Extract SIFT of 970.jpg image, 3968 of 4000 images
# Extract SIFT of 971.jpg image, 3969 of 4000 images
# Extract SIFT of 972.jpg image, 3970 of 4000 images
# Extract SIFT of 973.jpg image, 3971 of 4000 images
# Extract SIFT of 974.jpg image, 3972 of 4000 images
# Extract SIFT of 975.jpg image, 3973 of 4000 images
# Extract SIFT of 976.jpg image, 3974 of 4000 images
# Extract SIFT of 977.jpg image, 3975 of 4000 images
# Extract SIFT of 978.jpg image, 3976 of 4000 images
# Extract SIFT of 979.jpg image, 3977 of 4000 images
# Extract SIFT of 98.jpg image, 3978 of 4000 images
# Extract SIFT of 980.jpg image, 3979 of 4000 images
# Extract SIFT of 981.jpg image, 3980 of 4000 images
# Extract SIFT of 982.jpg image, 3981 of 4000 images
# Extract SIFT of 983.jpg image, 3982 of 4000 images
# Extract SIFT of 984.jpg image, 3983 of 4000 images
# Extract SIFT of 985.jpg image, 3984 of 4000 images
# Extract SIFT of 986.jpg image, 3985 of 4000 images
# Extract SIFT of 987.jpg image, 3986 of 4000 images
# Extract SIFT of 988.jpg image, 3987 of 4000 images
# Extract SIFT of 989.jpg image, 3988 of 4000 images
# Extract SIFT of 99.jpg image, 3989 of 4000 images
# Extract SIFT of 990.jpg image, 3990 of 4000 images
# Extract SIFT of 991.jpg image, 3991 of 4000 images
# Extract SIFT of 992.jpg image, 3992 of 4000 images
# Extract SIFT of 993.jpg image, 3993 of 4000 images
# Extract SIFT of 994.jpg image, 3994 of 4000 images
# Extract SIFT of 995.jpg image, 3995 of 4000 images
# Extract SIFT of 996.jpg image, 3996 of 4000 images
# Extract SIFT of 997.jpg image, 3997 of 4000 images
# Extract SIFT of 998.jpg image, 3998 of 4000 images
# Extract SIFT of 999.jpg image, 3999 of 4000 images

# %%
descriptors = des_list[0][1]
for image_path, descriptor in des_list[1:]:
    descriptors = np.vstack((descriptors, descriptor))  

# Perform k-means clustering
print("Start k-means: %d words, %d key points" %(numWords, descriptors.shape[0]))
voc, variance = kmeans(descriptors, numWords, 1) 

# Calculate the histogram of features
im_features = np.zeros((len(image_paths), numWords), "float32")
for i in range(len(image_paths)):
    words, distance = vq(des_list[i][1],voc)
    for w in words:
        im_features[i][w] += 1

# %%
# Perform Tf-Idf vectorization
nbr_occurences = np.sum( (im_features > 0) * 1, axis = 0)
idf = np.array(np.log((1.0*len(image_paths)+1) / (1.0*nbr_occurences + 1)), 'float32')

# Perform L2 normalization
im_features = im_features*idf
im_features = preprocessing.normalize(im_features, norm='l2')

joblib.dump((im_features, image_paths, idf, numWords, voc), "bof3.pkl", compress=3)
